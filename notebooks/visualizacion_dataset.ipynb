# %%
import pandas as pd

# %%
# Visualizaremos el dataset de forma bonita con pandas para poder apreciar mejor entidades y relaciones para el modelado de E/R: 
path = '../data/moto_results.csv'
pd.read_csv(path)
# Out:
#        year  sequence category rider_first_name rider_last_name  rider_number  \
# 0      2021        16    Moto2           Fermín        Aldeguer          54.0
# 1      2021        16    Moto2             Tony        Arbolino          14.0
# 2      2021        16    Moto2               Bo     Bendsneyder          64.0
# 3      2021        16    Moto2          Cameron        Beaubier           6.0
# 4      2021        16    Moto2           Marcel       Schrotter          23.0
# ...     ...       ...      ...              ...             ...           ...
# 29926  2000         1    500cc             Alex        Criville           NaN
# 29927  2000         1    500cc         Nobuatsu            Aoki           NaN
# 29928  2000         1    500cc             Alex          Barros           NaN
# 29929  2000         1    500cc            Kenny      Roberts Jr           NaN
# 29930  2000         1    500cc           Carlos           Checa           NaN
#
# ...
